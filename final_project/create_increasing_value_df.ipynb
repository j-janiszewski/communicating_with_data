# %%
import numpy as np
import pandas as pd

# %%
# read some dataframes
df = pd.read_csv('data/player_valuations_with_age_and_club.csv')
managers = pd.read_csv('data/manager_data.csv')
managers = managers[['club_id', 'manager', 'first_game', 'last_game']]

# %%
# add a manager column to the players df (this takes a while)
df['manager'] = None

for index, row in managers.iterrows():
    group_by_id = row['club_id']
    manager = row['manager']
    fg = row['first_game']
    lg = row['last_game']

    df.loc[(df['date'] >= fg) & (df['date'] <= lg) &
           (df['player_club_id'] == group_by_id), 'manager'] = manager

# %%
# add league id column to the players df
clubs = pd.read_csv('data/clubs.csv')
clubs = clubs[['club_id', 'domestic_competition_id', 'name']]
clubs = clubs.rename(columns={'club_id': 'player_club_id', 'name': 'club_name'})
df = df.merge(clubs, on='player_club_id', how='left')

# %%
# the first valuations don't have a club id and manager yet, but i don't think this is a problem
df
# Out:
#         player_id                        name  age_at_valuation    position  \
# 0           11757               Adam Kwarasey         24.553046  Goalkeeper
# 1           22474              Martin Örnskov         26.724162    Midfield
# 2           24112               Rune Jarstein         27.753593  Goalkeeper
# 3           26751               Johan Björdal         26.157426    Defender
# 4           37287           Tarik Elyounoussi         24.353183      Attack
# ...           ...                         ...               ...         ...
# 351247     896154                 Leonid Mina         19.482546      Attack
# 351248     932259   Konstantinos Chrysopoulos         20.336756    Defender
# 351249     950091             Stefanos Tzimas         17.705681      Attack
# 351250    1166093  Georgios Konstantakopoulos         18.724162    Midfield
# 351251     405676                 Oliver Bias         22.510609      Attack
#
#         height_in_cm   foot  market_value_in_eur        date  player_club_id  \
# 0              190.0  right               750000  2012-07-01             NaN
# 1              185.0   left              1000000  2012-07-01             NaN
# 2              192.0  right              1000000  2012-07-01             NaN
# 3              188.0  right               750000  2012-07-01             NaN
# 4              172.0  right              1500000  2012-07-01             NaN
# ...              ...    ...                  ...         ...             ...
# 351247         182.0  right               100000  2023-09-21          2671.0
# 351248         193.0   left               500000  2023-09-21          2441.0
# 351249         184.0   both              1000000  2023-09-21          1091.0
# 351250         182.0   both                50000  2023-09-21         30120.0
# 351251         164.0   both                50000  2023-12-19          1109.0
#
#                    manager domestic_competition_id          club_name
# 0                     None                     NaN                NaN
# 1                     None                     NaN                NaN
# 2                     None                     NaN                NaN
# 3                     None                     NaN                NaN
# 4                     None                     NaN                NaN
# ...                    ...                     ...                ...
# 351247                None                     GR1       PAS Giannina
# 351248                None                     GR1         AEK Athens
# 351249      Razvan Lucescu                     GR1  PAOK Thessaloniki
# 351250  Giannis Anastasiou                     GR1        AE Kifisias
# 351251                None                     NaN                NaN
#
# [351252 rows x 12 columns]

# %%
def get_value_increase(df, group_by_id, group_by='player_club_id', max_age_at_start=21,
                       max_age=24, min_stay=1, position="All", debug=False):
    """
    Get the median percentage increase in value per year for a group of players that meet the criteria:
    - their manager/club_id/domestic_competition_id matches the group_by_id
    - max_age_at_start: the maximum age at which the player started at the club/league/manager
    - max_age: keep only the player valuations that are below this age
    - min_stay: the minimum number of years the player has to stay at the club/league/manager
    - position: the position of the player

    - debug is True if you want to return the dataframe of selected players instead of the median increase
    """
    assert group_by in ['player_club_id', 'manager', 'domestic_competition_id']

    # select only the player valuations that meet the criteria
    all_valuations = df[df[group_by] == group_by_id]
    all_valuations = all_valuations[all_valuations['age_at_valuation'] < max_age]
    # sort by date
    all_valuations = all_valuations.sort_values(by='date')

    # keep only the players that match the given position
    if position != 'All':
        all_valuations = all_valuations[all_valuations['position'] == position]

    # group by player and get the first and last market value and age
    players = all_valuations.groupby(['player_id', 'name', 'position']).agg(
        {'market_value_in_eur': ['first', 'last'], 'age_at_valuation': ['first', 'last']})
    players.columns = ['first_market_value_in_eur', 'last_market_value_in_eur',
                       'first_age_at_valuation', 'last_age_at_valuation']
    players = players.reset_index()

    # compute the age difference
    players['age_diff'] = players['last_age_at_valuation'] - \
                          players['first_age_at_valuation']

    # remove players that have stayed less than min_stay years
    players = players[players['age_diff'] > min_stay]
    # remove players that started at an age higher than max_age_at_start
    players = players[players['first_age_at_valuation'] < max_age_at_start]

    # remove players that have less than 10 valuations (or 6 if position is not All)
    if position == 'All':
        if len(players) < 10:
            return None
    else:
        if len(players) < 6:
            return None

    # compute the percentage increase in value
    players['market_value_diff_percent'] = players['last_market_value_in_eur'] / \
                                           players['first_market_value_in_eur']

    # do the age_diff-th root of the percentage increase to get a comparison that is comparable per year
    players['market_value_diff_percent_per_year'] = players['market_value_diff_percent'].abs() ** \
                                                    (1 / players['age_diff'])
    # change NaN to -1 (idk if it is still needed)
    players['market_value_diff_percent_per_year'] = players['market_value_diff_percent_per_year'].fillna(-1)

    if debug:
        return players

    # return the median increase per year (mean is not good, because it is skewed by outliers like Mbappe)
    median_increase_per_year = players['market_value_diff_percent_per_year'].median()

    return median_increase_per_year

# %%
def get_value_increase_df(group_by):
    value_increases = []
    # skip Goalkeeper because there are too few players
    positions = ['All', 'Defender', 'Midfield', 'Attack']


    for position in positions:
        for group_by_id in df[group_by].unique():
            if group_by_id != group_by_id: # this apparently skips NaNs
                continue

            value_increase = get_value_increase(df, group_by_id, group_by=group_by, max_age_at_start=21,
                                                max_age=24, min_stay=1, position=position, debug=False)
            if value_increase is None:
                continue

            if group_by == 'player_club_id':
                club_name = clubs[clubs['player_club_id'] == group_by_id]['club_name'].values[0]
                row = (position, group_by_id, club_name, value_increase)
            else:
                row = (position, group_by_id, value_increase)

            print(row)
            value_increases.append(row)

    if group_by == 'player_club_id':
        value_increases = pd.DataFrame(value_increases, columns=['position', group_by, 'club_name', 'value_increase'])
    else:
        value_increases = pd.DataFrame(value_increases, columns=['position', group_by, 'value_increase'])
    return value_increases

club_value_increases = get_value_increase_df('player_club_id')
manager_value_increases = get_value_increase_df('manager')
league_value_increases = get_value_increase_df('domestic_competition_id')
# Out:
# ('All', 317.0, 'Twente Enschede FC', 1.1673817899094063)
# ('All', 190.0, 'FC Copenhagen', 1.6367144297484437)
# ('All', 865.0, 'FC Midtjylland', 1.6211678516411085)
# ('All', 2778.0, 'FC Nordsjaelland', 1.5981919504942883)
# ('All', 2414.0, 'AC Horsens', 1.409835869472015)
# ('All', 173.0, 'Odense Boldklub', 1.3247118617355953)
# ('All', 1177.0, 'Silkeborg IF', 1.6069478132847357)
# ('All', 5724.0, 'Randers FC', 1.3887010051876334)
# ('All', 678.0, 'Aarhus GF', 1.4387355457844178)
# ('All', 5817.0, 'SönderjyskE', 1.3681927838700618)
# ('All', 1053.0, 'Aalborg BK', 1.537684124497407)
# ('All', 206.0, 'Bröndby IF', 1.452552493370532)
# ('All', 3426.0, 'Esbjerg fB', 1.3744717366370196)
# ('All', 2578.0, 'St. Johnstone FC', 1.704262523948659)
# ('All', 964.0, 'Zenit St. Petersburg', 1.1681847800914817)
# ('All', 1083.0, 'FK Rostov', 1.1826045919888022)
# ('All', 3725.0, 'Akhmat Grozny', 1.2012780511110464)
# ('All', 121.0, 'Dynamo Moscow', 1.374558116585228)
# ('All', 932.0, 'Lokomotiv Moscow', 1.5937048988795457)
# ('All', 306.0, 'SC Heerenveen', 1.5078949021604513)
# ('All', 621.0, 'Athletic Bilbao', 1.273777676087394)
# ('All', 2698.0, 'Rubin Kazan', 1.26583027060735)
# ('All', 273.0, 'Stade Rennais FC', 1.373170549326741)
# ('All', 1049.0, 'Valencia CF', 1.4975670835501025)
# ('All', 150.0, 'Real Betis Balompié', 1.1931243952767077)
# ('All', 244.0, 'Olympique Marseille', 1.2378290950385855)
# ('All', 331.0, 'CA Osasuna', 1.1176086227661097)
# ('All', 1084.0, 'Málaga CF', 1.3709120949206457)
# ('All', 1041.0, 'Olympique Lyon', 1.6480571432704694)
# ('All', 1082.0, 'LOSC Lille', 1.5049430219281767)
# ('All', 618.0, 'AS Saint-Étienne', 1.4608531290361118)
# ('All', 583.0, 'Paris Saint-Germain', 1.3992770466049023)
# ('All', 1095.0, 'ESTAC Troyes', 1.7814914585980821)
# ('All', 417.0, 'OGC Nice', 1.3125024228183781)
# ('All', 2282.0, 'Club Brugge KV', 1.428859780255981)
# ('All', 86.0, 'SV Werder Bremen', 1.3054574106566583)
# ('All', 2441.0, 'AEK Athens', 1.1893328697228966)
# ('All', 27.0, 'Bayern Munich', 1.3215744580025597)
# ('All', 653.0, 'OFI Crete FC', 1.0660399301948533)
# ('All', 940.0, 'Celta de Vigo', 1.2936772876731957)
# ('All', 46.0, 'Inter Milan', 1.2006549057056248)
# ('All', 6992.0, 'Chornomorets Odessa', 1.0899641905222106)
# ('All', 660.0, 'Shakhtar Donetsk', 1.315701058897987)
# ('All', 338.0, 'Dynamo Kyiv', 1.4591712947107036)
# ('All', 339.0, 'Dnipro Dnipropetrovsk (-2020)', 1.31839280246135)
# ('All', 6994.0, 'Metalurg Zaporizhya (-2016)', 1.207113504216877)
# ('All', 415.0, 'FC Toulouse', 1.3713604394807266)
# ('All', 2477.0, 'Karpaty Lviv (-2021)', 1.0)
# ('All', 2439.0, 'Kuban Krasnodar (-2018)', 1.1591705136760324)
# ('All', 41.0, 'Hamburger SV', 1.2308593515384803)
# ('All', 294.0, 'SL Benfica', 1.4101718074024465)
# ('All', 610.0, 'Ajax Amsterdam', 1.8336728828252395)
# ('All', 5.0, 'AC Milan', 1.450713041472839)
# ('All', 1025.0, 'Bologna FC 1909', 1.0)
# ('All', 6993.0, 'FK Mariupol', 1.126742988452035)
# ('All', 3205.0, 'Kayserispor', 1.1437471771017087)
# ('All', 820.0, 'Genclerbirligi Ankara', 1.256843314817144)
# ('All', 20.0, 'Bursaspor', 1.2125626867496426)
# ('All', 379.0, 'West Ham United', 1.3357829134251)
# ('All', 29.0, 'Everton FC', 1.816374151639127)
# ('All', 148.0, 'Tottenham Hotspur', 1.4710715327894612)
# ('All', 405.0, 'Aston Villa', 1.5337504262597124)
# ('All', 762.0, 'Newcastle United', 1.3229064008337037)
# ('All', 31.0, 'Liverpool FC', 1.8275154797811812)
# ('All', 180.0, 'Southampton FC', 1.4358429833098492)
# ('All', 1184.0, 'KRC Genk', 1.6297013073405737)
# ('All', 720.0, 'FC Porto', 1.4694479207099609)
# ('All', 1426.0, 'VVV-Venlo', 1.2724873125151779)
# ('All', 11.0, 'Arsenal FC', 1.5154277494117134)
# ('All', 631.0, 'Chelsea FC', 1.6167246662197043)
# ('All', 430.0, 'ACF Fiorentina', 1.122030535249217)
# ('All', 2696.0, 'Krylya Sovetov Samara', 1.0886444563911364)
# ('All', 398.0, 'SS Lazio', 1.3668894943897456)
# ('All', 128.0, 'AO Xanthi', 1.2790062559925544)
# ('All', 370.0, 'Aberdeen FC', 1.5270909128557548)
# ('All', 465.0, 'St. Mirren FC', 1.3397318589206595)
# ('All', 1519.0, 'Dundee United FC', 1.4298757916259142)
# ('All', 371.0, 'Celtic FC', 1.3788975095224174)
# ('All', 987.0, 'Motherwell FC', 1.1650139987550896)
# ('All', 43.0, 'Heart of Midlothian FC', 1.2694643974463529)
# ('All', 2553.0, 'Kilmarnock FC', 1.2702375394248566)
# ('All', 204.0, 'Lierse SK (- 2018)', 1.1082330454273568)
# ('All', 3057.0, 'Standard Liège', 1.285228240255155)
# ('All', 172.0, 'RSC Charleroi', 1.2919075277409555)
# ('All', 498.0, 'KSC Lokeren (- 2020)', 1.058315138627958)
# ('All', 58.0, 'RSC Anderlecht', 1.5302050138618484)
# ('All', 157.0, 'KAA Gent', 1.1353072084538038)
# ('All', 3508.0, 'SV Zulte Waregem', 1.148528300043929)
# ('All', 601.0, 'KV Kortrijk', 1.067919115210244)
# ('All', 28643.0, 'SK Beveren', 1.0535746715067165)
# ('All', 683.0, 'Olympiacos Piraeus', 1.4267578714699354)
# ('All', 265.0, 'Panathinaikos Athens', 1.2888174322304868)
# ('All', 1091.0, 'PAOK Thessaloniki', 1.3737597526667291)
# ('All', 6676.0, 'Asteras Tripolis', 1.2768264618302705)
# ('All', 605.0, 'Aris Thessaloniki', 0.9195617861332432)
# ('All', 169.0, 'Panionios Athens', 1.2917370646505846)
# ('All', 2671.0, 'PAS Giannina', 1.3756108135353209)
# ('All', 21957.0, 'AO Platanias', 1.209678775500102)
# ('All', 403.0, 'Willem II Tilburg', 1.3206133502984507)
# ('All', 1090.0, 'AZ Alkmaar', 1.4384226778941591)
# ('All', 234.0, 'Feyenoord Rotterdam', 1.547287598498079)
# ('All', 499.0, 'Vitesse Arnhem', 1.6408095826207516)
# ('All', 383.0, 'PSV Eindhoven', 1.5400094139078524)
# ('All', 132.0, 'NAC Breda', 1.2394381900813412)
# ('All', 4482.0, 'Volyn Lutsk', 1.0784455722279667)
# ('All', 36.0, 'Fenerbahce', 1.1697181859236814)
# ('All', 533.0, 'TSG 1899 Hoffenheim', 1.4825085605616835)
# ('All', 18.0, 'Borussia Mönchengladbach', 1.5564467513013203)
# ('All', 24.0, 'Eintracht Frankfurt', 1.269455674405767)
# ('All', 42.0, 'Hannover 96', 1.119428148170503)
# ('All', 79.0, 'VfB Stuttgart', 1.1874465626908297)
# ('All', 39.0, '1.FSV Mainz 05', 1.501770877491905)
# ('All', 82.0, 'VfL Wolfsburg', 1.3812167496046586)
# ('All', 33.0, 'FC Schalke 04', 1.4271935980554233)
# ('All', 4.0, '1.FC Nuremberg', 0.9746135717971374)
# ('All', 15.0, 'Bayer 04 Leverkusen', 1.169378244550888)
# ('All', 167.0, 'FC Augsburg', 1.3064485849480016)
# ('All', 60.0, 'SC Freiburg', 1.69670479475131)
# ('All', 16.0, 'Borussia Dortmund', 1.4192286059672015)
# ('All', 3368.0, 'Levante UD', 1.4442630597895663)
# ('All', 252.0, 'Genoa CFC', 1.1406966227348343)
# ('All', 506.0, 'Juventus FC', 1.1061271246909516)
# ('All', 458.0, 'Palermo FC', 1.060245912818992)
# ('All', 2921.0, 'Delfino Pescara 1936', 0.9278776202511776)
# ('All', 12.0, 'AS Roma', 1.5453391958675526)
# ('All', 1075.0, 'SC Braga', 1.5154427729836624)
# ('All', 336.0, 'Sporting CP', 1.330644613804549)
# ('All', 354.0, 'KV Mechelen', 1.334750915042597)
# ('All', 2740.0, 'Vorskla Poltava', 1.1849042999710298)
# ('All', 6418.0, 'Panetolikos GFS', 1.220600267185201)
# ('All', 714.0, 'RCD Espanyol Barcelona', 1.6164497265735058)
# ('All', 368.0, 'Sevilla FC', 1.3781294900469307)
# ('All', 131.0, 'FC Barcelona', 1.0)
# ('All', 418.0, 'Real Madrid', 1.4758336788726274)
# ('All', 202.0, 'FC Groningen', 1.6577405862024999)
# ('All', 800.0, 'Atalanta BC', 1.4925919393944005)
# ('All', 13.0, 'Atlético de Madrid', 1.3147985266689757)
# ('All', 985.0, 'Manchester United', 1.3212511015554957)
# ('All', 141.0, 'Galatasaray', 1.0129156602861182)
# ('All', 3.0, '1.FC Köln', 1.4650806200246214)
# ('All', 589.0, 'Antalyaspor', 1.1934139999869189)
# ('All', 449.0, 'Trabzonspor', 1.1368521166882413)
# ('All', 524.0, 'Gaziantepspor (- 2020)', 0.9730323393367897)
# ('All', 114.0, 'Besiktas JK', 1.1971162865707083)
# ('All', 10484.0, 'Kasimpasa', 1.2142198157157784)
# ('All', 40.0, 'FC Girondins Bordeaux', 1.4290360458592686)
# ('All', 1158.0, 'FC Lorient', 1.4973689239653845)
# ('All', 969.0, 'Montpellier HSC', 1.55737855942888)
# ('All', 1421.0, 'Stade Reims', 1.7121023443280907)
# ('All', 2727.0, 'Oud-Heverlee Leuven', 1.009494550763664)
# ('All', 2420.0, 'Vitória Guimarães SC', 1.3209770524081104)
# ('All', 520.0, 'Cercle Brugge', 1.1236641807288263)
# ('All', 16795.0, 'Granada CF', 1.3248917475287922)
# ('All', 3709.0, 'Getafe CF', 1.6024293248786257)
# ('Defender', 631.0, 'Chelsea FC', 1.6167246662197043)
# ('Defender', 430.0, 'ACF Fiorentina', 1.1150817341925183)
# ('Defender', 371.0, 'Celtic FC', 1.75095992640002)
# ('Defender', 987.0, 'Motherwell FC', 1.3451431914313203)
# ('Defender', 43.0, 'Heart of Midlothian FC', 1.2694643974463529)
# ('Defender', 3057.0, 'Standard Liège', 1.2671798222266704)
# ('Defender', 172.0, 'RSC Charleroi', 1.5150789553853787)
# ('Defender', 58.0, 'RSC Anderlecht', 1.0579187512282011)
# ('Defender', 3508.0, 'SV Zulte Waregem', 1.1393764880296005)
# ('Defender', 28643.0, 'SK Beveren', 1.1382992257772782)
# ('Defender', 683.0, 'Olympiacos Piraeus', 1.192885815942252)
# ('Defender', 265.0, 'Panathinaikos Athens', 1.0)
# ('Defender', 1091.0, 'PAOK Thessaloniki', 1.3726768005568388)
# ('Defender', 21957.0, 'AO Platanias', 1.1972953950484304)
# ('Defender', 1090.0, 'AZ Alkmaar', 1.6896623527400563)
# ('Defender', 234.0, 'Feyenoord Rotterdam', 1.989827089401322)
# ('Defender', 499.0, 'Vitesse Arnhem', 1.2039411103960358)
# ('Defender', 383.0, 'PSV Eindhoven', 1.5385609643870106)
# ('Defender', 533.0, 'TSG 1899 Hoffenheim', 1.532903501496683)
# ('Defender', 18.0, 'Borussia Mönchengladbach', 1.6357049493042695)
# ('Defender', 82.0, 'VfL Wolfsburg', 1.6883862645737324)
# ('Defender', 33.0, 'FC Schalke 04', 1.4188570971482177)
# ('Defender', 15.0, 'Bayer 04 Leverkusen', 1.217645027600272)
# ('Defender', 60.0, 'SC Freiburg', 2.5010212349141043)
# ('Defender', 16.0, 'Borussia Dortmund', 1.16768364322584)
# ('Defender', 1075.0, 'SC Braga', 1.540387707461922)
# ('Defender', 354.0, 'KV Mechelen', 1.4761412408688823)
# ('Defender', 6418.0, 'Panetolikos GFS', 1.3176425513565806)
# ('Defender', 131.0, 'FC Barcelona', 1.2307944262480892)
# ('Defender', 202.0, 'FC Groningen', 1.1142947607096307)
# ('Defender', 13.0, 'Atlético de Madrid', 1.857060794852922)
# ('Defender', 985.0, 'Manchester United', 1.372539843636135)
# ('Defender', 3.0, '1.FC Köln', 1.0887494752030487)
# ('Defender', 449.0, 'Trabzonspor', 1.3762495977079081)
# ('Defender', 10484.0, 'Kasimpasa', 1.312791106930237)
# ('Defender', 40.0, 'FC Girondins Bordeaux', 1.315898170472244)
# ('Defender', 969.0, 'Montpellier HSC', 1.6744162251796995)
# ('Defender', 2420.0, 'Vitória Guimarães SC', 1.917134135881031)
# ('Defender', 520.0, 'Cercle Brugge', 1.1634478846689325)
# ('Defender', 16795.0, 'Granada CF', 1.3248917475287922)
# ('Defender', 369.0, 'Lyngby BK', 1.3978275242773284)
# ('Defender', 232.0, 'Spartak Moscow', 1.1176759830251644)
# ('Defender', 2410.0, 'CSKA Moscow', 1.4751915253324825)
# ('Defender', 200.0, 'FC Utrecht', 1.3286763691849275)
# ('Defender', 416.0, 'Torino FC', 1.41168904305689)
# ('Defender', 467.0, 'NEC Nijmegen', 1.2664250066720235)
# ('Attack', 371.0, 'Celtic FC', 1.353806768264263)
# ('Attack', 43.0, 'Heart of Midlothian FC', 1.4113492833646792)
# ('Attack', 2553.0, 'Kilmarnock FC', 1.4567155250033446)
# ('Attack', 204.0, 'Lierse SK (- 2018)', 1.0)
# ('Attack', 3057.0, 'Standard Liège', 1.3129699154392314)
# ('Attack', 172.0, 'RSC Charleroi', 1.0937134628518732)
# ('Attack', 498.0, 'KSC Lokeren (- 2020)', 1.0435161572675153)
# ('Attack', 58.0, 'RSC Anderlecht', 1.290942123825127)
# ('Attack', 157.0, 'KAA Gent', 1.3903527553613484)
# ('Attack', 3508.0, 'SV Zulte Waregem', 1.2319349946406617)
# ('Attack', 28643.0, 'SK Beveren', 1.0690879341458885)
# ('Attack', 683.0, 'Olympiacos Piraeus', 1.5303541398948248)
# ('Attack', 265.0, 'Panathinaikos Athens', 1.2169743418285357)
# ('Attack', 1091.0, 'PAOK Thessaloniki', 1.3947766420081633)
# ('Attack', 169.0, 'Panionios Athens', 1.355073659985263)
# ('Attack', 2671.0, 'PAS Giannina', 1.5129871677756097)
# ('Attack', 403.0, 'Willem II Tilburg', 1.3191715589834032)
# ('Attack', 1090.0, 'AZ Alkmaar', 1.494602566481086)
# ('Attack', 234.0, 'Feyenoord Rotterdam', 1.1633747258741316)
# ('Attack', 499.0, 'Vitesse Arnhem', 2.2009132465703694)
# ('Attack', 383.0, 'PSV Eindhoven', 1.8527616462114938)
# ('Attack', 132.0, 'NAC Breda', 1.25516108726805)
# ('Attack', 533.0, 'TSG 1899 Hoffenheim', 1.5417154617329405)
# ('Attack', 79.0, 'VfB Stuttgart', 1.2631531072764717)
# ('Attack', 33.0, 'FC Schalke 04', 1.184705738019577)
# ('Attack', 15.0, 'Bayer 04 Leverkusen', 1.2757387188509601)
# ('Attack', 16.0, 'Borussia Dortmund', 2.4047810781648846)
# ('Attack', 252.0, 'Genoa CFC', 1.0)
# ('Attack', 506.0, 'Juventus FC', 0.7805904837034371)
# ('Attack', 458.0, 'Palermo FC', 1.1204918256379843)
# ('Attack', 2921.0, 'Delfino Pescara 1936', 0.9616568928925571)
# ('Attack', 12.0, 'AS Roma', 1.3964615052681348)
# ('Attack', 1075.0, 'SC Braga', 1.4167457811259898)
# ('Attack', 336.0, 'Sporting CP', 1.5141925857761778)
# ('Attack', 368.0, 'Sevilla FC', 1.5220952658662723)
# ('Attack', 131.0, 'FC Barcelona', 1.0)
# ('Attack', 418.0, 'Real Madrid', 1.384173425806743)
# ('Attack', 202.0, 'FC Groningen', 2.126122460625464)
# ('Attack', 800.0, 'Atalanta BC', 1.0468460091102747)
# ('Attack', 13.0, 'Atlético de Madrid', 1.0015323499338113)
# ('Attack', 985.0, 'Manchester United', 1.907065479194033)
# ('Attack', 3.0, '1.FC Köln', 1.547831084167116)
# ('Attack', 589.0, 'Antalyaspor', 1.300143507320326)
# ('Attack', 524.0, 'Gaziantepspor (- 2020)', 0.8429301180861747)
# ('Attack', 114.0, 'Besiktas JK', 1.013488599565934)
# ('Attack', 40.0, 'FC Girondins Bordeaux', 2.2572611169068035)
# ('Attack', 969.0, 'Montpellier HSC', 1.1120541041679504)
# ('Attack', 2727.0, 'Oud-Heverlee Leuven', 1.0016993696031724)
# ('Attack', 2420.0, 'Vitória Guimarães SC', 0.8783384292467936)
# ('Attack', 520.0, 'Cercle Brugge', 1.1215606334834634)
# ('Attack', 3709.0, 'Getafe CF', 1.962403229278469)
# ('Attack', 369.0, 'Lyngby BK', 1.114157057995504)
# ('Attack', 232.0, 'Spartak Moscow', 1.2080054702601153)
# ('Attack', 2410.0, 'CSKA Moscow', 1.1855229694294653)
# ('Attack', 200.0, 'FC Utrecht', 1.2676648577123308)
# ('Attack', 16704.0, 'FK Krasnodar', 1.1312229473300086)
# ('Attack', 467.0, 'NEC Nijmegen', 1.6509166982184778)
# ('Attack', 1038.0, 'UC Sampdoria', 1.1009450490419415)
# ('Attack', 1268.0, 'ADO Den Haag', 1.7880895093677471)
# ('Attack', 1269.0, 'PEC Zwolle', 1.0546870580530485)
# ('Attack', 281.0, 'Manchester City', 1.5062758725658938)
# ('Attack', 979.0, 'Moreirense FC', 1.1383258156025207)
# ('Attack', 44.0, 'Hertha BSC', 1.2745912824999446)
# ('Attack', 8024.0, 'FC Arouca', 1.0)
# ('Attack', 162.0, 'AS Monaco', 1.2807310418633673)
# ('Attack', 6574.0, 'US Sassuolo', 1.1853369367666131)
# ('Attack', 1050.0, 'Villarreal CF', 1.6450758301775381)
# ('Attack', 2503.0, 'Boavista FC', 1.3826248072500753)
# ('Attack', 29228.0, 'Royal Excel Mouscron (-2022)', 1.1470893973228904)
# ('Attack', 347.0, 'FC Metz', 1.1426146815287856)
# ('Attack', 1420.0, 'Angers SCO', 1.9089896692404844)
# ('Attack', 23826.0, 'RB Leipzig', 1.1317654004735536)
# ('All', 'Kasper Hjulmand', 1.5775799106242714)
# ('All', 'Kent Nielsen', 1.6884400714734156)
# ('All', 'Kurban Berdyev', 1.3877590398219126)
# ('All', 'Rudi Garcia', 2.017027989927111)
# ('All', 'Christophe Galtier', 1.4610783887937178)
# ('All', 'Carlo Ancelotti', 1.1824434644778206)
# ('All', 'Claude Puel', 1.373064218313336)
# ('All', 'Roman Grygorchuk', 1.0534840935418748)
# ('All', 'Alain Casanova', 1.4651232020286535)
# ('All', 'Frank de Boer', 2.5796157067258303)
# ('All', 'Massimiliano Allegri', 1.2901025432422748)
# ('All', 'Stefano Pioli', 1.7059342856569286)
# ('All', 'Vincenzo Montella', 1.032620842171109)
# ('All', 'Neil Lennon', 1.296693772806722)
# ('All', 'Ron Jans', 1.499177574728206)
# ('All', 'Adrie Koster', 1.1806224433752452)
# ('All', 'Peter Maes', 1.2349070904850543)
# ('All', 'John van den Brom', 1.7439398379496596)
# ('All', 'Francky Dury', 1.1948044118628416)
# ('All', 'Leonardo Jardim', 1.7908213261475177)
# ('All', 'Lucien Favre', 1.6585325394610997)
# ('All', 'Bruno Labbadia', 1.3828739447716152)
# ('All', 'Thomas Tuchel', 1.133759024353645)
# ('All', 'Huub Stevens', 1.5623818554288085)
# ('All', 'Dieter Hecking', 1.23085427183352)
# ('All', 'Markus Weinzierl', 1.369981984018741)
# ('All', 'Christian Streich', 1.69670479475131)
# ('All', 'Jürgen Klopp', 1.65091669821848)
# ('All', 'Gian Piero Gasperini', 1.3502775613627405)
# ('All', 'Sérgio Conceição', 1.4879235251460765)
# ('All', 'Mauricio Pochettino', 2.0197908605200654)
# ('All', 'Michel', 1.4267578714699354)
# ('All', 'Ernesto Valverde', 1.288758518773075)
# ('All', 'Diego Simeone', 1.3147985266689757)
# ('All', 'Philippe Clement', 2.1962187414319767)
# ('All', 'Brian Priske', 1.5620756409224112)
# ('All', 'Valeriy Karpin', 1.099542634754421)
# ('All', 'Leonid Slutski', 1.4698035212702885)
# ('All', 'Unai Emery', 3.4133870296730304)
# ('All', 'Davide Ballardini', 1.28833395865165)
# ('All', 'Manuel Machado', 1.0973715913869113)
# ('All', 'Markus Gisdol', 1.5961924482669452)
# ('All', 'Erwin van de Looi', 1.8307822477456708)
# ('All', 'Thomas Frank', 1.1978091241379873)
# ('All', 'Felice Mazzù', 1.3660454203707373)
# ('All', 'Pep Guardiola', 1.8854420358495527)
# ('All', 'Giannis Anastasiou', 1.178121888317307)
# ('All', 'Michel Der Zakarian', 1.5123799788873267)
# ('All', 'Derek McInnes', 1.5238671182769914)
# ('All', 'Siniša Mihajlović', 0.9324218007032341)
# ('All', 'Ralph Hasenhüttl', 1.439965546997767)
# ('All', 'Henk Fraser', 1.8102659336536142)
# ('All', 'Ernest Faber', 1.537112514866169)
# ('All', 'Roman Sanzhar', 1.0)
# ('All', 'Yves Vanderhaeghe', 1.2073884828223371)
# ('All', 'Stale Solbakken', 1.6052391292852248)
# ('All', 'Roger Schmidt', 1.2617528991078286)
# ('All', 'Petit', 1.3553732570362045)
# ('All', 'Ismail Kartal', 1.0)
# ('All', 'Abdullah Avci', 1.222696172532876)
# ('All', 'Razvan Lucescu', 1.5046581122094336)
# ('All', 'Quique Sánchez Flores', 1.6553664532957608)
# ('All', 'Robbie Neilson', 1.162785063079256)
# ('All', 'Kemal Özdes', 1.7060329754138017)
# ('All', 'Pál Dárdai', 1.201991897297689)
# ('All', 'Oleksandr Babych', 1.1986438537899677)
# ('All', 'Giovanni van Bronckhorst', 1.6994103211376506)
# ('All', 'René Hake', 1.1214644834938547)
# ('All', 'Erik ten Hag', 1.7438807877638811)
# ('All', 'Marco Giampaolo', 1.0)
# ('All', 'David Nielsen', 1.8533661080299346)
# ('All', 'Bruno Génésio', 1.4579227679623252)
# ('All', 'Julian Nagelsmann', 1.5495723845385292)
# ('All', 'Zinédine Zidane', 1.601315619078552)
# ('All', 'Niko Kovac', 1.401113028664042)
# ('All', 'Viktor Goncharenko', 1.4292893514677047)
# ('All', 'Roberto De Zerbi', 1.565429626087353)
# ('All', 'Dick Lukkien', 1.512702051882786)
# ('All', 'Thomas Thomasberg', 1.8045950713967045)
# ('All', 'Imanol Alguacil', 1.5649343973768948)
# ('All', 'Danny Buijs', 1.3745699094450359)
# ('All', 'Johnny Jansen', 1.175791565151025)
# ('All', 'Arne Slot', 1.4267013515812694)
# ('All', 'João Pedro Sousa', 1.28088201244979)
# ('Defender', 'Kasper Hjulmand', 1.6417615599556927)
# ('Defender', 'Kent Nielsen', 1.6884400714734156)
# ('Defender', 'Alain Casanova', 1.348191528828736)
# ('Defender', 'Ron Jans', 2.0343165389665105)
# ('Defender', 'Francky Dury', 1.2170178831391418)
# ('Defender', 'Lucien Favre', 2.553431312644409)
# ('Defender', 'Huub Stevens', 3.1634639542525176)
# ('Defender', 'Dieter Hecking', 1.4938516124807053)
# ('Defender', 'Christian Streich', 2.5010212349141043)
# ('Defender', 'Jürgen Klopp', 1.6057038238160573)
# ('Defender', 'Michel', 1.192885815942252)
# ('Defender', 'Diego Simeone', 1.857060794852922)
# ('Defender', 'Philippe Clement', 2.1962187414319767)
# ('Defender', 'Brian Priske', 1.3250937825227083)
# ('Defender', 'Valeriy Karpin', 1.1542596606106015)
# ('Defender', 'Markus Gisdol', 1.5961924482669452)
# ('Defender', 'Siniša Mihajlović', 1.2110974417403721)
# ('Defender', 'Yves Vanderhaeghe', 1.3361160852744771)
# ('Defender', 'Petit', 2.4679521636618125)
# ('Defender', 'Erik ten Hag', 1.9463517745976286)
# ('Defender', 'Viktor Goncharenko', 1.6976014148048617)
# ('Midfield', 'Kasper Hjulmand', 1.4768157192703235)
# ('Midfield', 'Rudi Garcia', 4.749919736014299)
# ('Midfield', 'Ron Jans', 1.5410502389529408)
# ('Midfield', 'John van den Brom', 1.4291548086808392)
# ('Midfield', 'Francky Dury', 1.055933937048647)
# ('Midfield', 'Leonardo Jardim', 1.8627623612888446)
# ('Midfield', 'Lucien Favre', 1.2255159517165)
# ('Midfield', 'Bruno Labbadia', 1.1731843110819038)
# ('Midfield', 'Dieter Hecking', 1.348019121359543)
# ('Midfield', 'Markus Weinzierl', 1.2863249789649411)
# ('Midfield', 'Christian Streich', 1.3856923061283095)
# ('Midfield', 'Ernesto Valverde', 1.302487231274851)
# ('Midfield', 'Brian Priske', 1.5737955693928771)
# ('Midfield', 'Valeriy Karpin', 1.1574529209841278)
# ('Midfield', 'Unai Emery', 3.1320312302131352)
# ('Midfield', 'Erwin van de Looi', 1.686534763136713)
# ('Midfield', 'Niels Frederiksen', 1.7149858243665763)
# ('Midfield', 'Michel Der Zakarian', 1.3989194723967664)
# ('Midfield', 'Roger Schmidt', 1.1309023055760754)
# ('Midfield', 'Ismail Kartal', 0.9603009164513351)
# ('Midfield', 'Robbie Neilson', 1.231837407534086)
# ('Midfield', 'Erik ten Hag', 2.5590575126452024)
# ('Midfield', 'Marco Giampaolo', 0.8695414648450417)
# ('Midfield', 'Bruno Génésio', 2.536353792005424)
# ('Midfield', 'Niko Kovac', 1.401113028664042)
# ('Midfield', 'Viktor Goncharenko', 1.4052245054496804)
# ('Attack', 'Kent Nielsen', 1.6999971488858503)
# ('Attack', 'Christophe Galtier', 1.4772520710042305)
# ('Attack', 'Massimiliano Allegri', 1.0414927658369884)
# ('Attack', 'Ron Jans', 1.3032571008001048)
# ('Attack', 'Adrie Koster', 1.1806224433752452)
# ('Attack', 'Peter Maes', 1.419522878875213)
# ('Attack', 'Francky Dury', 1.2319349946406617)
# ('Attack', 'Leonardo Jardim', 1.0118816772233)
# ('Attack', 'Lucien Favre', 1.7048037983753215)
# ('Attack', 'Huub Stevens', 1.184705738019577)
# ('Attack', 'Michel', 1.64420832269921)
# ('Attack', 'Ernesto Valverde', 1.304906864328135)
# ('Attack', 'Diego Simeone', 1.0015323499338113)
# ('Attack', 'Brian Priske', 2.1428559055424174)
# ('Attack', 'Valeriy Karpin', 0.8380821762095485)
# ('Attack', 'Leonid Slutski', 1.304965222399863)
# ('Attack', 'Davide Ballardini', 1.0799742464170718)
# ('Attack', 'Felice Mazzù', 1.3712196613936685)
# ('Attack', 'Derek McInnes', 1.229338443606379)
# ('Attack', 'Siniša Mihajlović', 1.0042379915684232)
# ('Attack', 'Ernest Faber', 2.778877139152956)
# ('Attack', 'Petit', 1.230467995318957)
# ('Attack', 'Quique Sánchez Flores', 1.962403229278469)
# ('Attack', 'Pál Dárdai', 1.100228393479976)
# ('Attack', 'Erik ten Hag', 1.5123482694765242)
# ('Attack', 'David Nielsen', 1.7631854938772653)
# ('Attack', 'Bruno Génésio', 1.41697062874459)
# ('Attack', 'Thomas Thomasberg', 1.5652359042486874)
# ('Attack', 'Johnny Jansen', 1.3479348114751335)
# ('All', 'NL1', 1.366984513970264)
# ('All', 'UKR1', 1.1716705406675436)
# ('All', 'DK1', 1.4231391746424888)
# ('All', 'SC1', 1.3600314787140548)
# ('All', 'RU1', 1.2060478590019672)
# ('All', 'ES1', 1.3192886411538758)
# ('All', 'FR1', 1.4388024126476924)
# ('All', 'IT1', 1.1612765544402115)
# ('All', 'BE1', 1.2318827174113094)
# ('All', 'L1', 1.3249726581804335)
# ('All', 'GR1', 1.209678775500102)
# ('All', 'PO1', 1.2566524860626136)
# ('All', 'TR1', 1.0991011342914654)
# ('All', 'GB1', 1.419895747875416)
# ('Defender', 'NL1', 1.44548257371528)
# ('Defender', 'UKR1', 1.2400722713889607)
# ('Defender', 'DK1', 1.4235855269876023)
# ('Defender', 'SC1', 1.390658490243239)
# ('Defender', 'RU1', 1.2266055185567262)
# ('Defender', 'ES1', 1.4597375785236126)
# ('Defender', 'FR1', 1.606373074321656)
# ('Defender', 'IT1', 1.2444042403307913)
# ('Defender', 'BE1', 1.2535550762739207)
# ('Defender', 'L1', 1.463887716244705)
# ('Defender', 'GR1', 1.2195735585612395)
# ('Defender', 'PO1', 1.3899412224900076)
# ('Defender', 'TR1', 1.1631334975901537)
# ('Defender', 'GB1', 1.4773423741958014)
# ('Midfield', 'NL1', 1.3621997408473687)
# ('Midfield', 'UKR1', 1.130262824951057)
# ('Midfield', 'DK1', 1.3720350202516494)
# ('Midfield', 'SC1', 1.352763168163563)
# ('Midfield', 'RU1', 1.2328148700618908)
# ('Midfield', 'ES1', 1.2996667805967685)
# ('Midfield', 'FR1', 1.4290360458592686)
# ('Midfield', 'IT1', 1.1467038591886949)
# ('Midfield', 'BE1', 1.244166263591766)
# ('Midfield', 'L1', 1.2391426338273024)
# ('Midfield', 'GR1', 1.208138091412032)
# ('Midfield', 'PO1', 1.2355804792174256)
# ('Midfield', 'TR1', 1.0647261499762222)
# ('Midfield', 'GB1', 1.485838053984104)
# ('Attack', 'NL1', 1.3232059350334213)
# ('Attack', 'UKR1', 1.1924694082749272)
# ('Attack', 'DK1', 1.4906033119916162)
# ('Attack', 'SC1', 1.3269376275155138)
# ('Attack', 'RU1', 1.129970500928308)
# ('Attack', 'ES1', 1.2958829111229009)
# ('Attack', 'FR1', 1.293080581229424)
# ('Attack', 'IT1', 1.1424576908418131)
# ('Attack', 'BE1', 1.2132192671641997)
# ('Attack', 'L1', 1.286315109032347)
# ('Attack', 'GR1', 1.2493917771086678)
# ('Attack', 'PO1', 1.1522927390244042)
# ('Attack', 'TR1', 1.0633813422990452)
# ('Attack', 'GB1', 1.397833180137334)

# %%
# keep best 10 for each position in the df
def keep_n_best(df, n=10, worst=False):
    best = []
    for position in ['All', 'Defender', 'Midfield', 'Attack']:
        best.append(df[df['position'] == position].
                    sort_values(by='value_increase', ascending=worst).head(n))
    best = pd.concat(best)
    return best

best_clubs = keep_n_best(club_value_increases)
worst_leagues = keep_n_best(club_value_increases, worst=True)

# %%
club_value_increases
# Out:
#     position  player_club_id                     club_name  value_increase
# 0        All           317.0            Twente Enschede FC        1.167382
# 1        All           190.0                 FC Copenhagen        1.636714
# 2        All           865.0                FC Midtjylland        1.621168
# 3        All          2778.0              FC Nordsjaelland        1.598192
# 4        All          2414.0                    AC Horsens        1.409836
# ..       ...             ...                           ...             ...
# 547   Attack          2503.0                   Boavista FC        1.382625
# 548   Attack         29228.0  Royal Excel Mouscron (-2022)        1.147089
# 549   Attack           347.0                       FC Metz        1.142615
# 550   Attack          1420.0                    Angers SCO        1.908990
# 551   Attack         23826.0                    RB Leipzig        1.131765
#
# [552 rows x 4 columns]

# %%
# check the Nantes midfield players to see if they are really that good
get_value_increase(df, 995, group_by='player_club_id', max_age_at_start=21, max_age=24, min_stay=1,
                   position='Midfield', debug=True)
# Out:
#     player_id                name  position  first_market_value_in_eur  \
# 1      164771     Jordan Veretout  Midfield                    4500000
# 3      181382     Abdoulaye Touré  Midfield                     150000
# 8      228999       Alexis Alégué  Midfield                     150000
# 15     332889    Valentin Rongier  Midfield                     250000
# 19     463611      Abdoulaye Dabo  Midfield                    1000000
# 20     476527  Kenny Rocha Santos  Midfield                     150000
# 21     635336         Imrân Louza  Midfield                     300000
#
#     last_market_value_in_eur  first_age_at_valuation  last_age_at_valuation  \
# 1                    8000000               20.873374              22.264203
# 3                    5000000               20.429843              23.895962
# 8                     400000               18.885695              23.885010
# 15                  12000000               20.104038              23.748118
# 19                    500000               17.508556              21.314168
# 20                   1500000               19.414100              21.475702
# 21                  12000000               20.232717              22.094456
#
#     age_diff  market_value_diff_percent  market_value_diff_percent_per_year
# 1   1.390828                   1.777778                            1.512380
# 3   3.466119                  33.333333                            2.750181
# 8   4.999316                   2.666667                            1.216761
# 15  3.644079                  48.000000                            2.893093
# 19  3.805613                   0.500000                            0.833486
# 20  2.061602                  10.000000                            3.055342
# 21  1.861739                  40.000000                            7.253010

# %%
# save the dfs

best_clubs["position"]= best_clubs["position"].replace("Midfield","Midfielder")
best_clubs["position"]= best_clubs["position"].replace("Attack","Attacker")
best_clubs.to_csv("data/club_value_increase.csv")

# %%
worst_leagues.to_csv("data/club_value_increase.csv")
